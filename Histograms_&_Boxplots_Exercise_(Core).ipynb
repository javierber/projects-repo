# %% [markdown]
# <a href="https://colab.research.google.com/github/javierber/projects-repo/blob/main/Histograms_%26_Boxplots_Exercise_(Core).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task
# Complete & answer the following:
#
# TASK 1. Plot a histogram of the Percentage of Dog Owners.
#
# TASK 2. Plot a histogram of the Percentage of Cat Owners.
#
# TASK 3a. What can we see by comparing these two histograms? What information does this tell us?
#
# TASK 3b. Optional/Bonus: plot these two histograms on the same plot. An example of what this could look like is given below:
#
# ![histograms.png](data:image/png;base64,...)
#
# TASK 4. Create two boxplots on the same plot: one of the mean number of cats per household and the other of the mean number of dogs. An example of what this might look like is given below:
#
# ![boxplots.png](data:image/png;base64,...)
#
# TASK 5. What can we see by comparing these two boxplots? What information does this tell us?
#
# Turn in a notebook with your code and answers to these 5 questions.

# %%
#Mount
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Import
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#Load
filename = '/content/drive/MyDrive/Colab Notebooks/catsvdogs.xlsx'
df = pd.read_excel(filename, header = 0)
df.head()
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 12 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Location                            49 non-null     object
#  1   Number of Households (in 1000)      49 non-null     int64
#  2   Percentage of households with pets  49 non-null     float64
#  3   Number of Pet Households (in 1000)  49 non-null     int64
#  4   Percentage of Dog Owners            49 non-null     float64
#  5   Dog Owning Households (1000s)       49 non-null     int64
#  6   Mean Number of Dogs per household   49 non-null     float64
#  7   Dog Population (in 1000)            49 non-null     int64
#  8   Percentage of Cat Owners            49 non-null     float64
#  9   Cat Owning Households               49 non-null     int64
#  10  Mean Number of Cats                 49 non-null     float64
# ...

# %%
#TASK 1. Plot a histogram of the Percentage of Dog Owners.
df['Percentage of Dog Owners'].head()
df['Percentage of Dog Owners'].hist()

# %%
#TASK 2. Plot a histogram of the Percentage of Cat Owners.
df['Percentage of Cat Owners'].hist()

# %% [markdown]
# TASK 3a.
# What can we see by comparing these two histograms? What information does this tell us?
# Larger percentage of people in the us own dogs, while a large number own states have cat owners

# %%
#TASK 3b. Optional/Bonus: plot these two histograms on the same plot. 
df['Percentage of Dog Owners'].hist()
df['Percentage of Cat Owners'].hist()

# %%
#TASK 4. Create two boxplots on the same plot: one of the mean number of cats per household and the other of the mean number of dogs. 
cats = df['Mean Number of Cats'].values
dogs = df['Mean Number of Dogs per household'].values
plt.boxplot([cats,dogs], labels=['Cats','Dogs']);

# %% [markdown]
# TASK 5. What can we see by comparing these two boxplots? What information does this tell us?
# Turn in a notebook with your code and answers to these 5 questions.
#
# Of the mean number of households, lower of percentile own avg 2 cats  vs the mean number of hoseholds, large percentile owne 1.6 number of dogs.
